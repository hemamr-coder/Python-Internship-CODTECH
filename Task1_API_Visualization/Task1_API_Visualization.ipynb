# %%
import requests
import matplotlib.pyplot as plt

# %%
api_key = "8c8ee3d2add0b1c965cc2ebd5e95269d"
city = "Mysore"

url = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"

response = requests.get(url)
data = response.json()

print(data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1774332000, 'main': {'temp': 30, 'feels_like': 31.71, 'temp_min': 30, 'temp_max': 30.42, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 930, 'humidity': 54, 'temp_kf': -0.42}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 40}, 'wind': {'speed': 2.97, 'deg': 168, 'gust': 3.25}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-24 06:00:00'}, {'dt': 1774342800, 'main': {'temp': 31.34, 'feels_like': 32.03, 'temp_min': 31.34, 'temp_max': 34.01, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 926, 'humidity': 44, 'temp_kf': -2.67}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 31}, 'wind': {'speed': 3.43, 'deg': 141, 'gust': 3.29}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-24 09:00:00'}, {'dt': 1774353600, 'main': {'temp': 32.02, 'feels_like': 31.21, 'temp_min': 32.02, 'temp_max': 33.03, 'pressure': 1008, 'sea_level': 1008, 'grnd_level': 926, 'humidity': 33, 'temp_kf': -1.01}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 40}, 'wind': {'speed': 0.71, 'deg': 20, 'gust': 3.38}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-24 12:00:00'}, {'dt': 1774364400, 'main': {'temp': 26.75, 'feels_like': 27.35, 'temp_min': 26.75, 'temp_max': 26.75, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 929, 'humidity': 53, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 84}, 'wind': {'speed': 2.91, 'deg': 230, 'gust': 3.86}, 'visibility': 10000, 'pop': 0.74, 'rain': {'3h': 0.59}, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-24 15:00:00'}, {'dt': 1774375200, 'main': {'temp': 24.33, 'feels_like': 24.62, 'temp_min': 24.33, 'temp_max': 24.33, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 930, 'humidity': 69, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 52}, 'wind': {'speed': 2.98, 'deg': 283, 'gust': 5.27}, 'visibility': 10000, 'pop': 0.37, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-24 18:00:00'}, {'dt': 1774386000, 'main': {'temp': 23.49, 'feels_like': 23.72, 'temp_min': 23.49, 'temp_max': 23.49, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 929, 'humidity': 70, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 4}, 'wind': {'speed': 1.97, 'deg': 215, 'gust': 2.08}, 'visibility': 10000, 'pop': 0.81, 'rain': {'3h': 0.59}, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-24 21:00:00'}, {'dt': 1774396800, 'main': {'temp': 21.99, 'feels_like': 22.07, 'temp_min': 21.99, 'temp_max': 21.99, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 929, 'humidity': 70, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 5}, 'wind': {'speed': 2.67, 'deg': 173, 'gust': 5.67}, 'visibility': 10000, 'pop': 0.4, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-25 00:00:00'}, {'dt': 1774407600, 'main': {'temp': 25.3, 'feels_like': 25.35, 'temp_min': 25.3, 'temp_max': 25.3, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 931, 'humidity': 56, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 7}, 'wind': {'speed': 3.46, 'deg': 164, 'gust': 4.11}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-25 03:00:00'}, {'dt': 1774418400, 'main': {'temp': 30.88, 'feels_like': 30.12, 'temp_min': 30.88, 'temp_max': 30.88, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 931, 'humidity': 35, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 6}, 'wind': {'speed': 3.2, 'deg': 159, 'gust': 3.26}, 'visibility': 10000, 'pop': 0, 'sys': {'p ...

# %%
api_key = "8c8ee3d2add0b1c965cc2ebd5e95269d"

# %%
data['list']
# Out:
# [{'dt': 1774332000,
#   'main': {'temp': 30,
#    'feels_like': 31.71,
#    'temp_min': 30,
#    'temp_max': 30.42,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 930,
#    'humidity': 54,
#    'temp_kf': -0.42},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 40},
#   'wind': {'speed': 2.97, 'deg': 168, 'gust': 3.25},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-24 06:00:00'},
#  {'dt': 1774342800,
#   'main': {'temp': 31.34,
#    'feels_like': 32.03,
#    'temp_min': 31.34,
#    'temp_max': 34.01,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 926,
#    'humidity': 44,
#    'temp_kf': -2.67},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 31},
#   'wind': {'speed': 3.43, 'deg': 141, 'gust': 3.29},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-24 09:00:00'},
#  {'dt': 1774353600,
#   'main': {'temp': 32.02,
#    'feels_like': 31.21,
#    'temp_min': 32.02,
#    'temp_max': 33.03,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 926,
#    'humidity': 33,
#    'temp_kf': -1.01},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 40},
#   'wind': {'speed': 0.71, 'deg': 20, 'gust': 3.38},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-24 12:00:00'},
#  {'dt': 1774364400,
#   'main': {'temp': 26.75,
#    'feels_like': 27.35,
#    'temp_min': 26.75,
#    'temp_max': 26.75,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 53,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 2.91, 'deg': 230, 'gust': 3.86},
#   'visibility': 10000,
#   'pop': 0.74,
#   'rain': {'3h': 0.59},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-24 15:00:00'},
#  {'dt': 1774375200,
#   'main': {'temp': 24.33,
#    'feels_like': 24.62,
#    'temp_min': 24.33,
#    'temp_max': 24.33,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 930,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 52},
#   'wind': {'speed': 2.98, 'deg': 283, 'gust': 5.27},
#   'visibility': 10000,
#   'pop': 0.37,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-24 18:00:00'},
#  {'dt': 1774386000,
#   'main': {'temp': 23.49,
#    'feels_like': 23.72,
#    'temp_min': 23.49,
#    'temp_max': 23.49,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 1.97, 'deg': 215, 'gust': 2.08},
#   'visibility': 10000,
#   'pop': 0.81,
#   'rain': {'3h': 0.59},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-24 21:00:00'},
#  {'dt': 1774396800,
#   'main': {'temp': 21.99,
#    'feels_like': 22.07,
#    'temp_min': 21.99,
#    'temp_max': 21.99,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 929,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 5},
#   'wind': {'speed': 2.67, 'deg': 173, 'gust': 5.67},
#   'visibility': 10000,
#   'pop': 0.4,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-25 00:00:00'},
#  {'dt': 1774407600,
#   'main': {'temp': 25.3,
#    'feels_like': 25.35,
#    'temp_min': 25.3,
#    'temp_max': 25.3,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 931,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 7},
#   'wind': {'speed': 3.46, 'deg': 164, 'gust': 4.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-25 03:00:00'},
#  {'dt': 1774418400,
#   'main': {'temp': 30.88,
#    'feels_like': 30.12,
#    'temp_min': 30.88,
#    'temp_max': 30.88,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 931,
#    'humidity': 35,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 3.2, 'deg': 159, 'gust': 3.26},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-25 06:00:00'},
#  {'dt': 1774429200,
#   'main': {'temp': 34.68,
#    'feels_like': 33.06,
#    'temp_min': 34.68,
#    'temp_max': 34.68,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 927,
#    'humidity': 23,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 16},
#   'wind': {'speed': 3.99, 'deg': 124, 'gust': 3.89},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-25 09:00:00'},
#  {'dt': 1774440000,
#   'main': {'temp': 34.77,
#    'feels_like': 32.59,
#    'temp_min': 34.77,
#    'temp_max': 34.77,
#    'pressure': 1006,
#    'sea_level': 1006,
#    'grnd_level': 926,
#    'humidity': 18,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 25},
#   'wind': {'speed': 4.26, 'deg': 79, 'gust': 3.28},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-25 12:00:00'},
#  {'dt': 1774450800,
#   'main': {'temp': 28.5,
#    'feels_like': 28.45,
#    'temp_min': 28.5,
#    'temp_max': 28.5,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 44,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 2.95, 'deg': 237, 'gust': 3.79},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-25 15:00:00'},
#  {'dt': 1774461600,
#   'main': {'temp': 26.07,
#    'feels_like': 26.07,
#    'temp_min': 26.07,
#    'temp_max': 26.07,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 930,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 72},
#   'wind': {'speed': 1.54, 'deg': 278, 'gust': 1.89},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-25 18:00:00'},
#  {'dt': 1774472400,
#   'main': {'temp': 24.54,
#    'feels_like': 24.69,
#    'temp_min': 24.54,
#    'temp_max': 24.54,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 63,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 17},
#   'wind': {'speed': 1.82, 'deg': 198, 'gust': 2.99},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-25 21:00:00'},
#  {'dt': 1774483200,
#   'main': {'temp': 22.27,
#    'feels_like': 22.22,
#    'temp_min': 22.27,
#    'temp_max': 22.27,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 929,
#    'humidity': 64,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 12},
#   'wind': {'speed': 2.45, 'deg': 148, 'gust': 5.87},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-26 00:00:00'},
#  {'dt': 1774494000,
#   'main': {'temp': 26.54,
#    'feels_like': 26.54,
#    'temp_min': 26.54,
#    'temp_max': 26.54,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 932,
#    'humidity': 45,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 3.52, 'deg': 144, 'gust': 4.29},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-26 03:00:00'},
#  {'dt': 1774504800,
#   'main': {'temp': 32.97,
#    'feels_like': 31.24,
#    'temp_min': 32.97,
#    'temp_max': 32.97,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 931,
#    'humidity': 24,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 4.24, 'deg': 117, 'gust': 6.02},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-26 06:00:00'},
#  {'dt': 1774515600,
#   'main': {'temp': 35.8,
#    'feels_like': 33.69,
#    'temp_min': 35.8,
#    'temp_max': 35.8,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 927,
#    'humidity': 18,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 5.68, 'deg': 90, 'gust': 6.08},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-26 09:00:00'},
#  {'dt': 1774526400,
#   'main': {'temp': 34.5,
#    'feels_like': 32.31,
#    'temp_min': 34.5,
#    'temp_max': 34.5,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 926,
#    'humidity': 18,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 7.03, 'deg': 105, 'gust': 6.8},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-26 12:00:00'},
#  {'dt': 1774537200,
#   'main': {'temp': 29.31,
#    'feels_like': 28.02,
#    'temp_min': 29.31,
#    'temp_max': 29.31,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 28,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 17},
#   'wind': {'speed': 5.6, 'deg': 136, 'gust': 11.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-26 15:00:00'},
#  {'dt': 1774548000,
#   'main': {'temp': 25.23,
#    'feels_like': 25.27,
#    'temp_min': 25.23,
#    'temp_max': 25.23,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 930,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 9},
#   'wind': {'speed': 2.64, 'deg': 248, 'gust': 4.4},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-26 18:00:00'},
#  {'dt': 1774558800,
#   'main': {'temp': 23.02,
#    'feels_like': 23.39,
#    'temp_min': 23.02,
#    'temp_max': 23.02,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 929,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 2.06, 'deg': 227, 'gust': 3.19},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-26 21:00:00'},
#  {'dt': 1774569600,
#   'main': {'temp': 21.98,
#    'feels_like': 22.4,
#    'temp_min': 21.98,
#    'temp_max': 21.98,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 930,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 2.03, 'deg': 218, 'gust': 3.1},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-27 00:00:00'},
#  {'dt': 1774580400,
#   'main': {'temp': 25.57,
#    'feels_like': 25.83,
#    'temp_min': 25.57,
#    'temp_max': 25.57,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 931,
#    'humidity': 63,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 2.6, 'deg': 215, 'gust': 2.86},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-27 03:00:00'},
#  {'dt': 1774591200,
#   'main': {'temp': 32.68,
#    'feels_like': 31.36,
#    'temp_min': 32.68,
#    'temp_max': 32.68,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 930,
#    'humidity': 28,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 3},
#   'wind': {'speed': 2.89, 'deg': 147, 'gust': 3.92},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-27 06:00:00'},
#  {'dt': 1774602000,
#   'main': {'temp': 36.11,
#    'feels_like': 34.04,
#    'temp_min': 36.11,
#    'temp_max': 36.11,
#    'pressure': 1006,
#    'sea_level': 1006,
#    'grnd_level': 926,
#    'humidity': 18,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 7},
#   'wind': {'speed': 4.06, 'deg': 110, 'gust': 3.74},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-27 09:00:00'},
#  {'dt': 1774612800,
#   'main': {'temp': 35.14,
#    'feels_like': 32.98,
#    'temp_min': 35.14,
#    'temp_max': 35.14,
#    'pressure': 1005,
#    'sea_level': 1005,
#    'grnd_level': 925,
#    'humidity': 18,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 7},
#   'wind': {'speed': 4.36, 'deg': 83, 'gust': 2.69},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-27 12:00:00'},
#  {'dt': 1774623600,
#   'main': {'temp': 25.66,
#    'feels_like': 26.06,
#    'temp_min': 25.66,
#    'temp_max': 25.66,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 26},
#   'wind': {'speed': 7.22, 'deg': 251, 'gust': 10.42},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-27 15:00:00'},
#  {'dt': 1774634400,
#   'main': {'temp': 23.79,
#    'feels_like': 24.24,
#    'temp_min': 23.79,
#    'temp_max': 23.79,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 930,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 16},
#   'wind': {'speed': 5.04, 'deg': 256, 'gust': 7.67},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-27 18:00:00'},
#  {'dt': 1774645200,
#   'main': {'temp': 22.84,
#    'feels_like': 23.22,
#    'temp_min': 22.84,
#    'temp_max': 22.84,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 928,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 3.9, 'deg': 256, 'gust': 7.36},
#   'visibility': 10000,
#   'pop': 1,
#   'rain': {'3h': 1.63},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-27 21:00:00'},
#  {'dt': 1774656000,
#   'main': {'temp': 22.19,
#    'feels_like': 22.5,
#    'temp_min': 22.19,
#    'temp_max': 22.19,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 929,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 55},
#   'wind': {'speed': 2.11, 'deg': 283, 'gust': 4.61},
#   'visibility': 10000,
#   'pop': 1,
#   'rain': {'3h': 0.89},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-28 00:00:00'},
#  {'dt': 1774666800,
#   'main': {'temp': 26.4,
#    'feels_like': 26.4,
#    'temp_min': 26.4,
#    'temp_max': 26.4,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 930,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 41},
#   'wind': {'speed': 2.41, 'deg': 279, 'gust': 2.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-28 03:00:00'},
#  {'dt': 1774677600,
#   'main': {'temp': 31.73,
#    'feels_like': 30.99,
#    'temp_min': 31.73,
#    'temp_max': 31.73,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 929,
#    'humidity': 34,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 24},
#   'wind': {'speed': 3.27, 'deg': 295, 'gust': 1.86},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-28 06:00:00'},
#  {'dt': 1774688400,
#   'main': {'temp': 35.03,
#    'feels_like': 33.78,
#    'temp_min': 35.03,
#    'temp_max': 35.03,
#    'pressure': 1005,
#    'sea_level': 1005,
#    'grnd_level': 925,
#    'humidity': 25,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 23},
#   'wind': {'speed': 4.42, 'deg': 275, 'gust': 4.08},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-28 09:00:00'},
#  {'dt': 1774699200,
#   'main': {'temp': 30.23,
#    'feels_like': 29.61,
#    'temp_min': 30.23,
#    'temp_max': 30.23,
#    'pressure': 1006,
#    'sea_level': 1006,
#    'grnd_level': 925,
#    'humidity': 37,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 50},
#   'wind': {'speed': 6.26, 'deg': 0, 'gust': 5.51},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.16},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-28 12:00:00'},
#  {'dt': 1774710000,
#   'main': {'temp': 27.54,
#    'feels_like': 27.73,
#    'temp_min': 27.54,
#    'temp_max': 27.54,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 927,
#    'humidity': 47,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 4.43, 'deg': 256, 'gust': 7.94},
#   'visibility': 10000,
#   'pop': 0.5,
#   'rain': {'3h': 0.33},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-28 15:00:00'},
#  {'dt': 1774720800,
#   'main': {'temp': 24.77,
#    'feels_like': 25.08,
#    'temp_min': 24.77,
#    'temp_max': 24.77,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 928,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 76},
#   'wind': {'speed': 3.95, 'deg': 271, 'gust': 6.91},
#   'visibility': 10000,
#   'pop': 0.04,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-28 18:00:00'},
#  {'dt': 1774731600,
#   'main': {'temp': 22.71,
#    'feels_like': 23.1,
#    'temp_min': 22.71,
#    'temp_max': 22.71,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 927,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 63},
#   'wind': {'speed': 3.4, 'deg': 258, 'gust': 6.49},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-28 21:00:00'},
#  {'dt': 1774742400,
#   'main': {'temp': 21.72,
#    'feels_like': 22.14,
#    'temp_min': 21.72,
#    'temp_max': 21.72,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 928,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 62},
#   'wind': {'speed': 2.23, 'deg': 253, 'gust': 4.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-03-29 00:00:00'},
#  {'dt': 1774753200,
#   'main': {'temp': 24.81,
#    'feels_like': 25.12,
#    'temp_min': 24.81,
#    'temp_max': 24.81,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 930,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 2.59, 'deg': 249, 'gust': 2.53},
#   'visibility': 10000,
#   'pop': 0.09,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-03-29 03:00:00'}]

# %%
temps = []
times = []

for item in data['list'][:8]:
    temps.append(item['main']['temp'])
    times.append(item['dt_txt'])

print(temps)
print(times)
# Out:
# [30, 31.34, 32.02, 26.75, 24.33, 23.49, 21.99, 25.3]
# ['2026-03-24 06:00:00', '2026-03-24 09:00:00', '2026-03-24 12:00:00', '2026-03-24 15:00:00', '2026-03-24 18:00:00', '2026-03-24 21:00:00', '2026-03-25 00:00:00', '2026-03-25 03:00:00']

# %%
plt.figure(figsize=(10,5))
plt.plot(times, temps, marker='o')

plt.title("Temperature Forecast for Mysore")
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.savefig("weather_graph.png")
plt.show()
